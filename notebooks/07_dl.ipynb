# %%
import sys
sys.path.append('..')

import os
import json
import numpy as np
import pandas as pd
import joblib
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score
from sklearn.preprocessing import LabelEncoder, StandardScaler

from src.preprocess import preprocess, TARGET_ENCODE_COLS
from src.features import add_features
from src.train_dl import (
    run_experiment_fttransformer,
    run_experiment_saint,
    run_experiment_resnet,
    run_experiment_node,
)

# %%
run_experiment_resnet(
    name       = 'exp27_resnet_seed42',
    seed       = 42,
    start_fold = 1,
    batch_size = 512,
)

run_experiment_node(
    name       = 'exp28_node_seed42',
    seed       = 42,
    start_fold = 1,
    batch_size = 512,
)
# Out:
# Fold 1 | ROC-AUC: 0.7424 | PR-AUC: 0.4520
# Fold 2 | ROC-AUC: 0.7315 | PR-AUC: 0.4435
# Fold 3 | ROC-AUC: 0.7375 | PR-AUC: 0.4425
# Fold 4 | ROC-AUC: 0.7451 | PR-AUC: 0.4570
# Fold 5 | ROC-AUC: 0.7422 | PR-AUC: 0.4563
# Fold 6 | ROC-AUC: 0.7357 | PR-AUC: 0.4475
# Fold 7 | ROC-AUC: 0.7362 | PR-AUC: 0.4462
# Fold 8 | ROC-AUC: 0.7374 | PR-AUC: 0.4423
# Fold 9 | ROC-AUC: 0.7390 | PR-AUC: 0.4499
# Fold 10 | ROC-AUC: 0.7373 | PR-AUC: 0.4466
#
# CV Mean | ROC-AUC: 0.7384 | PR-AUC: 0.4484
# Fold 1 | ROC-AUC: 0.7413 | PR-AUC: 0.4514
# Fold 2 | ROC-AUC: 0.7312 | PR-AUC: 0.4468
# Fold 3 | ROC-AUC: 0.7370 | PR-AUC: 0.4449
# Fold 4 | ROC-AUC: 0.7444 | PR-AUC: 0.4561
# Fold 5 | ROC-AUC: 0.7413 | PR-AUC: 0.4554
# Fold 6 | ROC-AUC: 0.7358 | PR-AUC: 0.4448
# Fold 7 | ROC-AUC: 0.7343 | PR-AUC: 0.4446
# Fold 8 | ROC-AUC: 0.7357 | PR-AUC: 0.4404
# Fold 9 | ROC-AUC: 0.7385 | PR-AUC: 0.4479
# Fold 10 | ROC-AUC: 0.7369 | PR-AUC: 0.4468
#
# CV Mean | ROC-AUC: 0.7376 | PR-AUC: 0.4479
# ...
